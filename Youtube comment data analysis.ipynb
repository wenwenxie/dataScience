# %% [markdown]
# #### 0. Data Exploration and Cleaning

# %%
df_clean=spark.read.csv("/FileStore/tables/animals_comments.csv",inferSchema=True,header=True)
df_clean.show(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+------+-------------------------------------+
#         creator_name|userid|                              comment|
# +--------------------+------+-------------------------------------+
#         Doug The Pug|    87|                 I shared this to ...|
#         Doug The Pug|    87|                   Super cute  😀🐕🐶|
#          bulletproof|   530|                 stop saying get e...|
#        Meu Zoológico|   670|                 Tenho uma jiboia ...|
#               ojatro|  1031|                 I wanna see what ...|
#      Tingle Triggers|  1212|                 Well shit now Im ...|
# Hope For Paws - O...|  1806|                 when I saw the en...|
# Hope For Paws - O...|  2036|                 Holy crap. That i...|
#           Life Story|  2637|武器はクエストで貰えるんじゃないん...|
#        Brian Barczyk|  2698|                 Call the teddy Larry|
# +--------------------+------+-------------------------------------+
# only showing top 10 rows
#
# </div>

# %%
df_clean.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">166</span><span class="ansired">]: </span>471748</div>

# %%
df_clean = df_clean.na.drop(subset=["comment"])
df_clean.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">167</span><span class="ansired">]: </span>471662</div>

# %%
df_clean.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+------+-------------------------------------+
#         creator_name|userid|                              comment|
# +--------------------+------+-------------------------------------+
#         Doug The Pug|    87|                 I shared this to ...|
#         Doug The Pug|    87|                   Super cute  😀🐕🐶|
#          bulletproof|   530|                 stop saying get e...|
#        Meu Zoológico|   670|                 Tenho uma jiboia ...|
#               ojatro|  1031|                 I wanna see what ...|
#      Tingle Triggers|  1212|                 Well shit now Im ...|
# Hope For Paws - O...|  1806|                 when I saw the en...|
# Hope For Paws - O...|  2036|                 Holy crap. That i...|
#           Life Story|  2637|武器はクエストで貰えるんじゃないん...|
#        Brian Barczyk|  2698|                 Call the teddy Larry|
#             The Dodo|  2702|                   😐🤔😓😢😭😭😭😭😟|
# Hope For Paws - O...|  2911|                 That mother cat l...|
# Hope For Paws - O...|  2911|                 Its people like H...|
#    Talking Kitty Cat|  2911|                 steve: No wet foo...|
#     Brave Wilderness|  3224|                 Dont call this a ...|
#           MaxluvsMya|  3267|                 why are you alway...|
# Rise Up Society F...|  3372|                           Deb Tucker|
#             The Dodo|  3466|                 Thats a deer isnt...|
#     Brave Wilderness|  3466|                 there is no safe ...|
#     Brave Wilderness|  3466|                 Red before yellow...|
# +--------------------+------+-------------------------------------+
# only showing top 20 rows
#
# </div>

# %%
# find user with preference of dog and cat
from pyspark.sql.functions import when
from pyspark.sql.functions import col

# you can user your ways to extract the label

df_clean = df_clean.withColumn("label", \
                           (when(col("comment").like("%my dog%"), 1) \
                           .when(col("comment").like("%I have a dog%"), 1) \
                           .when(col("comment").like("%my cat%"), 1) \
                           .when(col("comment").like("%I have a cat%"), 1) \
                           .when(col("comment").like("%my puppy%"), 1) \
                           .when(col("comment").like("%my pup%"), 1) \
                           .when(col("comment").like("%my kitty%"), 1) \
                           .when(col("comment").like("%my pussy%"), 1) \
                           .otherwise(0)))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_clean.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+------+-------------------------------------+-----+
#         creator_name|userid|                              comment|label|
# +--------------------+------+-------------------------------------+-----+
#         Doug The Pug|    87|                 I shared this to ...|    0|
#         Doug The Pug|    87|                   Super cute  😀🐕🐶|    0|
#          bulletproof|   530|                 stop saying get e...|    0|
#        Meu Zoológico|   670|                 Tenho uma jiboia ...|    0|
#               ojatro|  1031|                 I wanna see what ...|    0|
#      Tingle Triggers|  1212|                 Well shit now Im ...|    0|
# Hope For Paws - O...|  1806|                 when I saw the en...|    0|
# Hope For Paws - O...|  2036|                 Holy crap. That i...|    0|
#           Life Story|  2637|武器はクエストで貰えるんじゃないん...|    0|
#        Brian Barczyk|  2698|                 Call the teddy Larry|    0|
#             The Dodo|  2702|                   😐🤔😓😢😭😭😭😭😟|    0|
# Hope For Paws - O...|  2911|                 That mother cat l...|    0|
# Hope For Paws - O...|  2911|                 Its people like H...|    0|
#    Talking Kitty Cat|  2911|                 steve: No wet foo...|    0|
#     Brave Wilderness|  3224|                 Dont call this a ...|    0|
#           MaxluvsMya|  3267|                 why are you alway...|    0|
# Rise Up Society F...|  3372|                           Deb Tucker|    0|
#             The Dodo|  3466|                 Thats a deer isnt...|    0|
#     Brave Wilderness|  3466|                 there is no safe ...|    0|
#     Brave Wilderness|  3466|                 Red before yellow...|    0|
# +--------------------+------+-------------------------------------+-----+
# only showing top 20 rows
#
# </div>

# %% [markdown]
# #### 1. Data preprocessing and Build the classifier

# %%
from pyspark.ml.feature import RegexTokenizer, Word2Vec
from pyspark.ml.classification import LogisticRegression

# regular expression tokenizer
regexTokenizer = RegexTokenizer(inputCol="comment", outputCol="words", pattern="\\W")

word2Vec = Word2Vec(inputCol="words", outputCol="features")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.ml import Pipeline

pipeline = Pipeline(stages=[regexTokenizer, word2Vec])

# Fit the pipeline to training documents.
pipelineFit = pipeline.fit(df_clean)
dataset = pipelineFit.transform(df_clean)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dataset.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+------+-------------------------------------+-----+--------------------+--------------------+
#         creator_name|userid|                              comment|label|               words|            features|
# +--------------------+------+-------------------------------------+-----+--------------------+--------------------+
#         Doug The Pug|    87|                 I shared this to ...|    0|[i, shared, this,...|[0.06693919409405...|
#         Doug The Pug|    87|                   Super cute  😀🐕🐶|    0|       [super, cute]|[-0.1368178129196...|
#          bulletproof|   530|                 stop saying get e...|    0|[stop, saying, ge...|[0.20635336502031...|
#        Meu Zoológico|   670|                 Tenho uma jiboia ...|    0|[tenho, uma, jibo...|[-0.1134413468341...|
#               ojatro|  1031|                 I wanna see what ...|    0|[i, wanna, see, w...|[0.23843675699423...|
#      Tingle Triggers|  1212|                 Well shit now Im ...|    0|[well, shit, now,...|[0.09472853112965...|
# Hope For Paws - O...|  1806|                 when I saw the en...|    0|[when, i, saw, th...|[0.09578964012044...|
# Hope For Paws - O...|  2036|                 Holy crap. That i...|    0|[holy, crap, that...|[0.22311756365860...|
#           Life Story|  2637|武器はクエストで貰えるんじゃないん...|    0|                  []|         (100,[],[])|
#        Brian Barczyk|  2698|                 Call the teddy Larry|    0|[call, the, teddy...|[0.16921564005315...|
#             The Dodo|  2702|                   😐🤔😓😢😭😭😭😭😟|    0|                  []|         (100,[],[])|
# Hope For Paws - O...|  2911|                 That mother cat l...|    0|[that, mother, ca...|[0.12041414554484...|
# Hope For Paws - O...|  2911|                 Its people like H...|    0|[its, people, lik...|[0.06866260132519...|
#    Talking Kitty Cat|  2911|                 steve: No wet foo...|    0|[steve, no, wet, ...|[0.12430505674671...|
#     Brave Wilderness|  3224|                 Dont call this a ...|    0|[dont, call, this...|[0.16988174544115...|
#           MaxluvsMya|  3267|                 why are you alway...|    0|[why, are, you, a...|[0.06188083822780...|
# Rise Up Society F...|  3372|                           Deb Tucker|    0|       [deb, tucker]|[-0.0851886644959...|
#             The Dodo|  3466|                 Thats a deer isnt...|    0|[thats, a, deer, ...|[0.04441467970609...|
#     Brave Wilderness|  3466|                 there is no safe ...|    0|[there, is, no, s...|[0.11001019913922...|
#     Brave Wilderness|  3466|                 Red before yellow...|    0|[red, before, yel...|[0.11626194646725...|
# +--------------------+------+-------------------------------------+-----+--------------------+--------------------+
# only showing top 20 rows
#
# </div>

# %%
(lable0_train,lable0_test)=dataset.filter(col('label')==1).randomSplit([0.7, 0.3],seed = 100)
(lable1_train, lable1_ex)=dataset.filter(col('label')==0).randomSplit([0.005, 0.995],seed = 100)
(lable1_test, lable1_ex2)=lable1_ex.randomSplit([0.002, 0.998],seed = 100)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
lable1_ex2.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">175</span><span class="ansired">]: </span>465292</div>

# %%
trainingData = lable0_train.union(lable1_train)
testData=lable0_test.union(lable1_test)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print("Dataset Count: " + str(dataset.count()))
print("Training Dataset Count: " + str(trainingData.count()))
print("Test Dataset Count: " + str(testData.count()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Dataset Count: 471662
# Training Dataset Count: 4515
# Test Dataset Count: 1855
# </div>

# %% [markdown]
# ##### LogisticRegression

# %%
lr = LogisticRegression(featuresCol = 'features', labelCol = 'label', maxIter=10)
lrModel = lr.fit(trainingData)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
predictions = lrModel.transform(testData)
predictions.select('label', 'prediction', 'probability','creator_name','userid').show(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+----------+--------------------+----------------+-------+
# label|prediction|         probability|    creator_name| userid|
# +-----+----------+--------------------+----------------+-------+
#     1|       1.0|[0.16677063782134...|  Big Cat Rescue| 315612|
#     1|       1.0|[0.23022623638489...|  Big Cat Rescue|2477786|
#     1|       1.0|[0.02847034951782...|         Brandon|1500606|
#     1|       1.0|[0.39764220414300...|Brave Wilderness| 346987|
#     1|       1.0|[0.42730594616571...|Brave Wilderness| 929599|
#     1|       1.0|[0.13234094772007...|Brave Wilderness|1255228|
#     1|       1.0|[9.89772229046496...|Brave Wilderness|1400234|
#     1|       1.0|[0.16240799087922...|Brave Wilderness|1767265|
#     1|       0.0|[0.93673748135252...|Brave Wilderness|2182581|
#     1|       1.0|[3.79787752486361...|   Brian Barczyk| 127220|
# +-----+----------+--------------------+----------------+-------+
# only showing top 10 rows
#
# </div>

# %%
from pyspark.ml.evaluation import BinaryClassificationEvaluator
evaluator = BinaryClassificationEvaluator()
print('Test Area Under ROC', evaluator.evaluate(predictions))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Test Area Under ROC 0.9569183553331148
# </div>

# %% [markdown]
# ##### Parameter Tuning and K-fold cross-validation

# %%
from pyspark.ml.tuning import ParamGridBuilder, CrossValidator

# Create ParamGrid for Cross Validation
paramGrid = (ParamGridBuilder()
             .addGrid(lr.regParam, [0.01, 0.5, 2.0])
             .addGrid(lr.elasticNetParam, [0.0, 0.5, 1.0])
             .addGrid(lr.maxIter, [1, 5, 10])
             .build())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Create 5-fold CrossValidator
cv = CrossValidator(estimator=lr, estimatorParamMaps=paramGrid, evaluator=evaluator, numFolds=5)

# Run cross validations
cvModel_lr = cv.fit(trainingData)
# Use test set to measure the accuracy of our model on new data
predictions = cvModel_lr.transform(testData)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
predictions_lr = cvModel_lr.transform(testData)
print("Test Area Under ROC: " + str(evaluator.evaluate(predictions)))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Test Area Under ROC: 0.957833946441992
# </div>

# %%
selected = predictions_lr.select('label', 'prediction', 'probability','creator_name','userid')
display(selected)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>label</th><th>prediction</th><th>probability</th><th>creator_name</th><th>userid</th></tr></thead><tbody><tr><td>1</td><td>1.0</td><td>List(1, 2, List(), List(0.27544027080082545, 0.7245597291991744))</td><td>Big Cat Rescue</td><td>315612</td></tr><tr><td>1</td><td>1.0</td><td>List(1, 2, List(), List(0.2777782910741955, 0.7222217089258045))</td><td>Big Cat Rescue</td><td>2477786</td></tr><tr><td>1</td><td>1.0</td><td>List(1, 2, List(), List(0.07664810768814397, 0.9233518923118561))</td><td>Brandon</td><td>1500606</td></tr><tr><td>1</td><td>1.0</td><td>List(1, 2, List(), List(0.29307622070444944, 0.7069237792955506))</td><td>Brave Wilderness</td><td>346987</td></tr><tr><td>1</td><td>1.0</td><td>List(1, 2, List(), List(0.4934544006846522, 0.5065455993153478))</td><td>Brave Wilderness</td><td>929599</td></tr><tr><td>1</td><td>1.0</td><td>List(1, 2, List(), List(0.1679985697131536, 0.8320014302868464))</td><td>Brave Wilderness</td><td>1255228</td></tr><tr><td>1</td><td>1.0</td><td>List(1, 2, List(), List(0.007314693902205931, 0.9926853060977942))</td><td>Brave Wilderness</td><td>1400234</td></tr><tr><td>1</td><td>1.0</td><td>List(1, 2, List(), List(0.21193344892556062, 0.7880665510744393))</td><td>Brave Wilderness</td><td>1767265</td></tr><tr><td>1</td><td>0.0</td><td>List(1, 2, List(), List(0.8815505753848388, 0.11844942461516116))</td><td>Brave Wilderness</td><td>2182581</td></tr><tr><td>1</td><td>1.0</td><td>List(1, 2, List(), List(0.0030220866717503053, 0.9969779133282496))</td><td>Brian Barczyk</td><td>127220</td></tr><tr><td>1</td><td>0.0</td><td>List(1, 2, List(), List(0.5576086190359265, 0.44239138096407343))</td><td>Brian Barczyk</td><td>1411818</td></tr><tr><td>1</td><td>1.0</td><td>List(1, 2, List(), List(0.11355186332591652, 0.8864481366740834))</td><td>Brian Barczyk</td><td>1460462</td></tr><tr><td>1</td><td>1.0</td><td>List(1, 2, List(), List(0.00550583385190886, 0.994494166148091))</td><td>Brian Barczyk</td><td>1638794</td></tr><tr><td>1</td><td>1.0</td><td>List(1, 2, List(), List(0.1247268150300066, 0.8752731849699934))</td><td>Cat Man Chris</td><td>1896503</td></tr><tr><td>1</td><td>1.0</td><td>List(1, 2, List(), List(0.05355356592869177, 0.9464464340713084))</td><td>Cat Man Chris</td><td>2462891</td></tr><tr><td>1</td><td>1.0</td><td>List(1, 2, List(), List(0.1513793990223081, 0.848620600977692))</td><td>Chris Cheng</td><td>303890</td></tr><tr><td>1</td><td>1.0</td><td>List(1, 2, List(), List(0.1412685811603972, 0.8587314188396028))</td><td>Cole & Marmalade</td><td>263721</td></tr><tr><td>1</td><td>1.0</td><td>List(1, 2, List(), List(0.03606551745929038, 0.9639344825407096))</td><td>Cole & Marmalade</td><td>524721</td></tr><tr><td>1</td><td>1.0</td><td>List(1, 2, List(), List(0.17420480113744435, 0.8257951988625557))</td><td>Cole & Marmalade</td><td>846766</td></tr><tr><td>1</td><td>1.0</td><td>List(1, 2, List(), List(0.2789363532550788, 0.7210636467449212))</td><td>Cole & Marmalade</td><td>908794</td></tr><tr><td>1</td><td>1.0</td><td>List(1, 2, List(), List(0.016446316033937, 0.983553683966063))</td><td>Cole & Marmalade</td><td>1137028</td></tr><tr><td>1</td><td>1.0</td><td>List(1, 2, List(), List(0.00345606347654134, 0.9965439365234586))</td><td>Cole & Marmalade</td><td>1271312</td></tr><tr><td>1</td><td>1.0</td><td>List(1, 2, List(), List(0.1855180101658695, 0.8144819898341304))</td><td>Cole & Marmalade</td><td>1416828</td></tr><tr><td>1</td><td>1.0</td><td>List(1, 2, List(), List(0.3402061377054347, 0.6597938622945653))</td><td>Cole & Marmalade</td><td>1630566</td></tr><tr><td>1</td><td>1.0</td><td>List(1, 2, List(), List(0.4411191353604059, 0.5588808646395941))</td><td>Cole & Marmalade</td><td>1896503</td></tr><tr><td>1</td><td>1.0</td><td>List(1, 2, List(), List(0.30847458884473794, 0.691525411155262))</td><td>Cole & Marmalade</td><td>2360523</td></tr><tr><td>1</td><td>1.0</td><td>List(1,  ...

# %% [markdown]
# ##### RandomForest

# %%
from pyspark.ml.classification import RandomForestClassifier

# Create an initial RandomForest model.
rf = RandomForestClassifier(labelCol="label", featuresCol="features")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.ml.tuning import ParamGridBuilder, CrossValidator

paramGrid = (ParamGridBuilder()
             .addGrid(rf.maxDepth, [2, 4, 6])
             .addGrid(rf.maxBins, [20, 60])
             .addGrid(rf.numTrees, [5, 20])
             .build())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Create 5-fold CrossValidator
cv = CrossValidator(estimator=rf, estimatorParamMaps=paramGrid, evaluator=evaluator, numFolds=5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
cvModel_rf = cv.fit(trainingData)
# Use test set to measure the accuracy of our model on new data
predictions_rf = cvModel_rf.transform(testData)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print("Test Area Under ROC: " + str(evaluator.evaluate(predictions_rf)))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Test Area Under ROC: 0.9580928016157219
# </div>

# %%
selected = predictions_rf.select('label', 'prediction', 'probability','creator_name','userid')
display(selected)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>label</th><th>prediction</th><th>probability</th><th>creator_name</th><th>userid</th></tr></thead><tbody><tr><td>1</td><td>1.0</td><td>List(1, 2, List(), List(0.34420877239561476, 0.6557912276043851))</td><td>Big Cat Rescue</td><td>315612</td></tr><tr><td>1</td><td>1.0</td><td>List(1, 2, List(), List(0.3037094733943609, 0.6962905266056392))</td><td>Big Cat Rescue</td><td>2477786</td></tr><tr><td>1</td><td>0.0</td><td>List(1, 2, List(), List(0.5750667195607656, 0.42493328043923445))</td><td>Brandon</td><td>1500606</td></tr><tr><td>1</td><td>0.0</td><td>List(1, 2, List(), List(0.5622846696063767, 0.4377153303936233))</td><td>Brave Wilderness</td><td>346987</td></tr><tr><td>1</td><td>0.0</td><td>List(1, 2, List(), List(0.6001523825609952, 0.39984761743900477))</td><td>Brave Wilderness</td><td>929599</td></tr><tr><td>1</td><td>1.0</td><td>List(1, 2, List(), List(0.44206563503091434, 0.5579343649690857))</td><td>Brave Wilderness</td><td>1255228</td></tr><tr><td>1</td><td>1.0</td><td>List(1, 2, List(), List(0.17571210718932412, 0.8242878928106758))</td><td>Brave Wilderness</td><td>1400234</td></tr><tr><td>1</td><td>1.0</td><td>List(1, 2, List(), List(0.35868260360929727, 0.6413173963907027))</td><td>Brave Wilderness</td><td>1767265</td></tr><tr><td>1</td><td>0.0</td><td>List(1, 2, List(), List(0.8017677770967515, 0.19823222290324857))</td><td>Brave Wilderness</td><td>2182581</td></tr><tr><td>1</td><td>1.0</td><td>List(1, 2, List(), List(0.19247219615548347, 0.8075278038445164))</td><td>Brian Barczyk</td><td>127220</td></tr><tr><td>1</td><td>1.0</td><td>List(1, 2, List(), List(0.3634275151832473, 0.6365724848167527))</td><td>Brian Barczyk</td><td>1411818</td></tr><tr><td>1</td><td>1.0</td><td>List(1, 2, List(), List(0.19824485798759534, 0.8017551420124047))</td><td>Brian Barczyk</td><td>1460462</td></tr><tr><td>1</td><td>1.0</td><td>List(1, 2, List(), List(0.19398943103690752, 0.8060105689630925))</td><td>Brian Barczyk</td><td>1638794</td></tr><tr><td>1</td><td>1.0</td><td>List(1, 2, List(), List(0.22617476564534486, 0.7738252343546552))</td><td>Cat Man Chris</td><td>1896503</td></tr><tr><td>1</td><td>1.0</td><td>List(1, 2, List(), List(0.24442222437972944, 0.7555777756202706))</td><td>Cat Man Chris</td><td>2462891</td></tr><tr><td>1</td><td>1.0</td><td>List(1, 2, List(), List(0.16445924954527594, 0.8355407504547241))</td><td>Chris Cheng</td><td>303890</td></tr><tr><td>1</td><td>1.0</td><td>List(1, 2, List(), List(0.1786442546040605, 0.8213557453959395))</td><td>Cole & Marmalade</td><td>263721</td></tr><tr><td>1</td><td>1.0</td><td>List(1, 2, List(), List(0.17921470619965826, 0.8207852938003418))</td><td>Cole & Marmalade</td><td>524721</td></tr><tr><td>1</td><td>1.0</td><td>List(1, 2, List(), List(0.2754786923520632, 0.7245213076479369))</td><td>Cole & Marmalade</td><td>846766</td></tr><tr><td>1</td><td>1.0</td><td>List(1, 2, List(), List(0.24768551316905824, 0.7523144868309417))</td><td>Cole & Marmalade</td><td>908794</td></tr><tr><td>1</td><td>1.0</td><td>List(1, 2, List(), List(0.19944927649872274, 0.8005507235012772))</td><td>Cole & Marmalade</td><td>1137028</td></tr><tr><td>1</td><td>1.0</td><td>List(1, 2, List(), List(0.16028201371670545, 0.8397179862832945))</td><td>Cole & Marmalade</td><td>1271312</td></tr><tr><td>1</td><td>1.0</td><td>List(1, 2, List(), List(0.32010445427494, 0.6798955457250601))</td><td>Cole & Marmalade</td><td>1416828</td></tr><tr><td>1</td><td>1.0</td><td>List(1, 2, List(), List(0.42729486589006394, 0.572705134109936))</td><td>Cole & Marmalade</td><td>1630566</td></tr><tr><td>1</td><td>1.0</td><td>List(1, 2, List(), List(0.2928781876837191, 0.707121812316281))</td><td>Cole & Marmalade</td><td>1896503</td></tr><tr><td>1</td><td>1.0</td><td>List(1, 2, List(), List(0.20333654293727785, 0.7966634570627221))</td><td>Cole & Marmalade</td><td>2360523</td></tr><tr><td>1</td><td>1.0</td><td>List(1 ...

# %% [markdown]
# ##### Gradient boosting

# %%
from pyspark.ml.classification import GBTClassifier
gbt = GBTClassifier(maxIter=10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
paramGrid = ParamGridBuilder()\
  .addGrid(gbt.maxDepth, [2, 5])\
  .addGrid(gbt.maxIter, [10, 20])\
  .build()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
cv = CrossValidator(estimator=gbt, estimatorParamMaps=paramGrid, evaluator=evaluator, numFolds=5)
cvModel_gbt = cv.fit(trainingData)
# Use test set to measure the accuracy of our model on new data
predictions_gbt = cvModel_gbt.transform(testData)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
predictions_gbt.select('label', 'prediction', 'probability','creator_name','userid').show(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+----------+--------------------+----------------+-------+
# label|prediction|         probability|    creator_name| userid|
# +-----+----------+--------------------+----------------+-------+
#     1|       1.0|[0.13170394249540...|  Big Cat Rescue| 315612|
#     1|       1.0|[0.24802553641832...|  Big Cat Rescue|2477786|
#     1|       0.0|[0.79557832947238...|         Brandon|1500606|
#     1|       0.0|[0.66394991320972...|Brave Wilderness| 346987|
#     1|       0.0|[0.70443525640051...|Brave Wilderness| 929599|
#     1|       0.0|[0.62714319217593...|Brave Wilderness|1255228|
#     1|       1.0|[0.06614732342886...|Brave Wilderness|1400234|
#     1|       1.0|[0.12074200884013...|Brave Wilderness|1767265|
#     1|       0.0|[0.79392545107978...|Brave Wilderness|2182581|
#     1|       1.0|[0.07274278874106...|   Brian Barczyk| 127220|
# +-----+----------+--------------------+----------------+-------+
# only showing top 10 rows
#
# </div>

# %%
evaluator = BinaryClassificationEvaluator()
print("Test Area Under ROC: " + str(evaluator.evaluate(predictions)))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Test Area Under ROC: 0.9578339464419919
# </div>

# %% [markdown]
# #### As Random Forest gives us the best ROC evaludation, we will use Random Forest as our best model to generate predictions on the all the users.

# %%
bestModel = cvModel_rf.bestModel
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #### 2. Classify All The Users

# %%
# Generate predictions for entire dataset
finalPredictions = bestModel.transform(dataset)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Evaluate best model
evaluator.evaluate(finalPredictions)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">198</span><span class="ansired">]: </span>0.9635931695696572</div>

# %%
selected = finalPredictions.select('label', 'prediction', 'probability','creator_name','userid','comment','words')
display(selected)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>label</th><th>prediction</th><th>probability</th><th>creator_name</th><th>userid</th><th>comment</th><th>words</th></tr></thead><tbody><tr><td>0</td><td>1.0</td><td>List(1, 2, List(), List(0.1891011195151004, 0.8108988804848996))</td><td>Doug The Pug</td><td>87</td><td>I shared this to my friends and mom the were lol</td><td>List(i, shared, this, to, my, friends, and, mom, the, were, lol)</td></tr><tr><td>0</td><td>0.0</td><td>List(1, 2, List(), List(0.957407239583751, 0.04259276041624897))</td><td>Doug The Pug</td><td>87</td><td>Super cute  😀🐕🐶</td><td>List(super, cute)</td></tr><tr><td>0</td><td>0.0</td><td>List(1, 2, List(), List(0.5528723497388928, 0.44712765026110723))</td><td>bulletproof</td><td>530</td><td>stop saying get em youre literally dumb . have some common sense or dont own this kind of dog. fucking retarded I swear</td><td>List(stop, saying, get, em, youre, literally, dumb, have, some, common, sense, or, dont, own, this, kind, of, dog, fucking, retarded, i, swear)</td></tr><tr><td>0</td><td>0.0</td><td>List(1, 2, List(), List(0.9539685649462936, 0.04603143505370649))</td><td>Meu Zoológico</td><td>670</td><td>Tenho uma jiboia e um largato</td><td>List(tenho, uma, jiboia, e, um, largato)</td></tr><tr><td>0</td><td>0.0</td><td>List(1, 2, List(), List(0.7097968958589418, 0.2902031041410582))</td><td>ojatro</td><td>1031</td><td>I wanna see what happened to the pigs after that  please</td><td>List(i, wanna, see, what, happened, to, the, pigs, after, that, please)</td></tr><tr><td>0</td><td>0.0</td><td>List(1, 2, List(), List(0.7113389885156643, 0.28866101148433554))</td><td>Tingle Triggers</td><td>1212</td><td>Well shit now Im hungry</td><td>List(well, shit, now, im, hungry)</td></tr><tr><td>0</td><td>1.0</td><td>List(1, 2, List(), List(0.18987383820734594, 0.8101261617926541))</td><td>Hope For Paws - Official Rescue Channel</td><td>1806</td><td>when I saw the end it said to adopt  I saw different animal sites I was mad that they separated the cute little pups after being  together for a long time</td><td>List(when, i, saw, the, end, it, said, to, adopt, i, saw, different, animal, sites, i, was, mad, that, they, separated, the, cute, little, pups, after, being, together, for, a, long, time)</td></tr><tr><td>0</td><td>0.0</td><td>List(1, 2, List(), List(0.5365549306814937, 0.46344506931850626))</td><td>Hope For Paws - Official Rescue Channel</td><td>2036</td><td>Holy crap. That is quite literally the most adorable pup Ive ever seen.</td><td>List(holy, crap, that, is, quite, literally, the, most, adorable, pup, ive, ever, seen)</td></tr><tr><td>0</td><td>0.0</td><td>List(1, 2, List(), List(0.9892600454480907, 0.01073995455190938))</td><td>Life Story</td><td>2637</td><td>武器はクエストで貰えるんじゃないんですか？</td><td>List()</td></tr><tr><td>0</td><td>0.0</td><td>List(1, 2, List(), List(0.9274100934024766, 0.07258990659752333))</td><td>Brian Barczyk</td><td>2698</td><td>Call the teddy Larry</td><td>List(call, the, teddy, larry)</td></tr><tr><td>0</td><td>0.0</td><td>List(1, 2, List(), List(0.9892600454480907, 0.01073995455190938))</td><td>The Dodo</td><td>2702</td><td>😐🤔😓😢😭😭😭😭😟</td><td>List()</td></tr><tr><td>0</td><td>1.0</td><td>List(1, 2, List(), List(0.15792153581822074, 0.8420784641817792))</td><td>Hope For Paws - Official Rescue Channel</td><td>2911</td><td>That mother cat looks like my own Im guessing she is a russian blue due to her looks and unusual coping skills.</td><td>List(that, mother, cat, looks, like, my, own, im, guessing, she, is, a, russian, blue, due, to, her, looks, and, unusual, coping, skills)</td></tr><tr><td>0</td><td>1.0</td><td>List(1, 2, List(), List(0.46929115790614306, 0.5307088420938569))</td><td>Hope For Paws - Official Rescue Channel</td><td>2911</td><td>Its people like Hope For Paws who truly make the world a better place <3</td><td>List(its, people, like, hope, for, paws, who, truly, ma ...

# %%
from pyspark.sql.functions import col
fraction = selected.where(col('prediction')==1).count()/selected.count()
print("The fraction of all users who have dogs/cats is estimated to be %.2f."%fraction)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The fraction of all users who have dogs/cats is estimated to be 0.14.
# </div>

# %% [markdown]
# #### 3. Get insigts of Users

# %%
from pyspark.ml.feature import CountVectorizer
from pyspark.ml.feature import IDF
from pyspark.ml.feature import StopWordsRemover

owners = selected.where(col('prediction')==1)
remover = StopWordsRemover(inputCol="words", outputCol="filtered")
owners = remover.transform(owners)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
cv = CountVectorizer(inputCol="filtered", outputCol="rawFeatures", vocabSize = 1000)
cvmodel = cv.fit(owners)
featurizedData = cvmodel.transform(owners)

vocab = cvmodel.vocabulary
vocab_broadcast = sc.broadcast(vocab)

idf = IDF(inputCol="rawFeatures", outputCol="features")
idfModel = idf.fit(featurizedData)
rescaledData = idfModel.transform(featurizedData)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.ml.clustering import LDA
# Generate 25 Data-Driven Topics:
# "em" = expectation-maximization 
lda = LDA(k=25, seed=123, optimizer="em", featuresCol="features")
ldamodel = lda.fit(rescaledData)
ldatopics = ldamodel.describeTopics()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.sql.functions import udf
from pyspark.sql.types import StringType
def indiciestowords(value):
  words = []
  for idx in value:
    words.append(vocab[idx])
  return ','.join(words)
sparkudf = udf(indiciestowords,StringType())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
topic_words = ldatopics.withColumn('topics',sparkudf(col('termIndices'))).select('topic','topics')

display(topic_words)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>topic</th><th>topics</th></tr></thead><tbody><tr><td>0</td><td>like,dog,one,love,im,people,get,dont,cat,know</td></tr><tr><td>1</td><td>like,one,dog,im,get,love,cat,dont,got,know</td></tr><tr><td>2</td><td>like,one,dog,love,im,get,cat,dont,got,know</td></tr><tr><td>3</td><td>like,one,dog,im,love,get,dont,people,know,cat</td></tr><tr><td>4</td><td>hermit,crab,crabs,like,one,dog,get,love,im,dont</td></tr><tr><td>5</td><td>dog,like,wolf,pitbull,one,get,dogs,dont,im,people</td></tr><tr><td>6</td><td>like,one,love,dog,betta,get,im,dont,cat,want</td></tr><tr><td>7</td><td>like,dog,one,get,love,im,dont,woman,know,people</td></tr><tr><td>8</td><td>horse,horses,saddle,like,get,one,ride,dont,dog,im</td></tr><tr><td>9</td><td>dog,like,one,love,n,im,get,cat,dogs,dont</td></tr><tr><td>10</td><td>like,dog,one,love,get,im,dont,people,cat,know</td></tr><tr><td>11</td><td>like,wear,dog,helmet,one,horse,riding,get,im,dont</td></tr><tr><td>12</td><td>like,one,love,dog,im,get,dont,know,got,cat</td></tr><tr><td>13</td><td>guinea,pigs,dog,like,one,love,dogs,get,50,im</td></tr><tr><td>14</td><td>mother,sister,father,woman,brother,cat,like,kitten,one,kittens</td></tr><tr><td>15</td><td>like,one,dog,love,get,cat,im,rats,got,dont</td></tr><tr><td>16</td><td>like,dog,one,love,im,get,dont,cat,people,know</td></tr><tr><td>17</td><td>dog,like,one,love,im,get,cat,dogs,want,dont</td></tr><tr><td>18</td><td>like,dog,love,im,one,get,dont,know,u,people</td></tr><tr><td>19</td><td>like,one,love,dog,get,im,cat,dont,want,got</td></tr><tr><td>20</td><td>like,dog,one,love,get,im,cat,dont,got,dogs</td></tr><tr><td>21</td><td>like,dog,one,love,cat,im,get,dogs,got,dont</td></tr><tr><td>22</td><td>dog,like,love,one,cat,im,get,cats,dont,know</td></tr><tr><td>23</td><td>like,dog,one,love,get,im,dont,dogs,got,know</td></tr><tr><td>24</td><td>like,dog,one,love,get,im,molly,dont,know,cat</td></tr></tbody></table></div>

# %% [markdown]
# From the above topics, looks like the topics that dog and cat owners most concerned are: Dog,Cat,like,love,horses,father,mother,pitbull,kitten.

# %% [markdown]
# #### 4.  Identify Creators With Cat And Dog Owners In The Audience Find creators with the most cat and/or dog owners. Find creators with the highest statistically significant percentages of cat and/or dog owners.

# %%
creator = owners.groupBy('creator_name').count().orderBy('count',ascending=False).collect()
print("The creator with the most cat/dog owners is %s." % creator[0]['creator_name'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The creator with the most cat/dog owners is Brave Wilderness.
# </div>

# %%
from pyspark.sql.functions import * 
selected.columns
dcowners = selected.groupBy("creator_name").agg({'prediction':'sum'})
totalnumbers = selected.groupBy("creator_name").count()
percentage = totalnumbers.join(dcowners,'creator_name',how='inner').withColumn('percentage',round(dcowners['sum(prediction)']/totalnumbers['count'],2))
percentage.select('creator_name','percentage').orderBy('percentage',ascending=False).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+----------+
#         creator_name|percentage|
# +--------------------+----------+
#               tehAon|       1.0|
#      BFranklinCrafts|       1.0|
#         818 Concepts|       1.0|
#            Bully Max|       1.0|
#            MrDidrill|       1.0|
#          Convo Relay|       1.0|
#       LY Chinchillas|       1.0|
# Sit Means Sit Dog...|       1.0|
#           phreaktor1|       1.0|
#       JaysontehHusky|       1.0|
#           Groomer TV|       1.0|
# San Antonio Human...|       1.0|
#        Robert Giroux|       1.0|
# MiraculousLoversS...|       1.0|
#        HonestKitchen|       1.0|
#              TJ Ring|       1.0|
#              arliowa|       1.0|
#      The Paw Project|       1.0|
#                Hartz|       1.0|
# Aphmau X anime fo...|       1.0|
# +--------------------+----------+
# only showing top 20 rows
#
# </div>

# %% [markdown]
# #### 5. Analysis and Future work

# %% [markdown]
# 1. overview of project :
#
#   The goal of the project is by examining the comments and useId of animal related videos and predict if they are dog or cat owners, identify the common important topics that these users are most concerned.
#
# 2. data clean and modeling:
#
#   First, we did data processing, checking counts and drop any null values in the comment column. We labeled some data as dog/cat owners if we find the comments include words like my dog, I have dog. And then we created a pipeline to tokenize and vectorized the words. Next, we split the data into train and test data and ready to feed them into a machine learning algorithm.
# 3. data analysis
#
#   We checked the counts and percentage of the dog/cat owners per creator, and select the creators with the highest amount of dog/cat owners and percentage of dog/cat owners.
#   We analyzed the common important topics that most dog/cat owners are concerned about.
# 4. build ml model
#
#   We used spark ML pipeline: Tokenizer -> HashTF -> LogisticRegression to build the classifier to predict dog/cat owners. We also tried ParamGrid to tune hyper parameters and cross vaidation to choose the best model. We also tried Random Forest and Gradient Boosting models and decided that Random Forest gives us the best results.
#   We also used LDA model to identify the topics among dog/cat owners.
# 5. recommendation based on the model results
#
#   From the topics, we can tell what the dog/cat owners think most important to them thus we can recommend videos with these topics to them.
